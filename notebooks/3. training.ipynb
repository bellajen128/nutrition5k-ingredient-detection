# %%
# === Nutrition5K Project Notebook Setup ===
import sys, os, subprocess

VENV_DIR = "/home/jen.che/nutrition5k_env"
SITE_PACKAGES = f"{VENV_DIR}/lib/python3.12/site-packages"

# 把虛擬環境加入 sys.path
if SITE_PACKAGES not in sys.path:
    sys.path.insert(0, SITE_PACKAGES)
print(f"Activated venv: {VENV_DIR}")

# 測試 torch + GPU 狀態
try:
    import torch
    print(f"Torch {torch.__version__} | CUDA: {torch.cuda.is_available()}")
    if torch.cuda.is_available():
        print(f"GPU: {torch.cuda.get_device_name(0)}")
except ImportError:
    print("Torch not found — installing basic packages...")
    subprocess.run([
        f"{VENV_DIR}/bin/python", "-m", "pip", "install",
        "torch", "timm==0.9.16", "effdet==0.4.1", "pycocotools==2.0.8", "opencv-python==4.9.0.80"
    ])
    import torch
    print(f"Torch installed successfully — version {torch.__version__}")

# 可選：載入常用路徑
DATASET_DIR = "/scratch/jen.che/nutrition5k_cache/datasets/siddhantrout/nutrition5k-dataset"
PREPARED_DIR = "/scratch/jen.che/nutrition5k_prepared"
os.makedirs(PREPARED_DIR, exist_ok=True)
print(f"Dataset: {DATASET_DIR}")
print(f"Prepared data: {PREPARED_DIR}")
# Out:
# Activated venv: /home/jen.che/nutrition5k_env
# Torch not found — installing basic packages...
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 24
#      19     print("Torch not found — installing basic packages...")
#      20     subprocess.run([
#      21         f"{VENV_DIR}/bin/python", "-m", "pip", "install",
#      22         "torch", "timm==0.9.16", "effdet==0.4.1", "pycocotools==2.0.8", "opencv-python==4.9.0.80"
#      23     ])
# ---> 24     import torch
#      25     print(f"Torch installed successfully — version {torch.__version__}")
#      27 # 可選：載入常用路徑
#
# File ~/nutrition5k_env/lib/python3.12/site-packages/torch/__init__.py:1013
#    1011     # The __file__ check only works for Python 3.7 and above.
#    1012     if _C_for_compiled_check.__file__ is None:
# ...

# %%
#!/bin/bash
# check_gpu_env.sh - 檢查你的 GPU 環境

echo "=== GPU Information ==="
nvidia-smi

echo -e "\n=== CUDA Version ==="
nvcc --version

echo -e "\n=== Python Environment ==="
which python
python --version

echo -e "\n=== Virtual Environment ==="
source /home/jen.che/nutrition5k_env/bin/activate
which python
python -c "import torch; print(f'PyTorch: {torch.__version__}'); print(f'CUDA Available: {torch.cuda.is_available()}')"
# Out:
#   Cell In[5], line 4
#     echo "=== GPU Information ==="
#          ^
# SyntaxError: invalid syntax
